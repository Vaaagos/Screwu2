# %% [markdown]
# # Настройка Git

# %%
# !git config --global user.name "Maksimkakir"
# !git config --global user.email "mj292580@gmail.com"

# %% [markdown]
# # Перейдем в папку и подключимся к диску

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/Vaaagos/Screwu2.git
# Out:
# fatal: destination path 'Screwu2' already exists and is not an empty directory.

# %%
# !mv conspects_KirichekMA.ipynb Screwu2/

# %%
cd /content/drive/MyDrive/Colab Notebooks/Screwu2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Screwu2

# %% [markdown]
# #Математика Pyton

# %% [markdown]
# # Зона для коммитов

# %% [markdown]
# # Передадим файл в репозиторий

# %%
# !git status
# Out:
# Refresh index: 100% (2/2), done.
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	conspects_KirichekMA.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   conspects_KirichekMA.ipynb

# %%
# !git commit -m "Добавил свой новый файл в репозиторий"
# Out:
# [master 73c97ba] Добавил свой новый файл в репозиторий
#  1 file changed, 1 insertion(+)
#  create mode 100644 conspects_KirichekMA.ipynb

# %%
token = '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'
username = 'Vaaagos'
repo = 'Screwu2'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Vaaagos/Screwu2.git (fetch)
# origin	https://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@github.com/Vaaagos/Screwu2.git (push)

# %%
# !git push origin master
# Out:
# To https://github.com/Vaaagos/Screwu2.git
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://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@github.com/Vaaagos/Screwu2.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
