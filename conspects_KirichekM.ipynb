# %% [markdown]
# # Настройка Git

# %%
# !git config --global user.name "Maksimkakir"
# !git config --global user.email "mj292580@gmail.com"

# %%
token = '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'
username = 'Vaaagos'
repo = 'Screwu2'

# %% [markdown]
# # Перейдем в папку и подключимся к диску

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/Vaaagos/Screwu2.git
# Out:
# Cloning into 'Screwu2'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 27 (delta 7), reused 26 (delta 6), pack-reused 0
# Unpacking objects: 100% (27/27), 13.50 KiB | 1.04 MiB/s, done.

# %%
# !mv conspects_KirichekM.ipynb Screwu2/

# %%
cd /content/drive/MyDrive/Colab Notebooks/Screwu2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Screwu2

# %% [markdown]
# # Математика Python
# * какие математические операции можно проводить с числами в Python?
# * Приведите примеры и найдите 3 отличия от классической математики.
# * Используйте ячейки кода и текста в Google Colab

# %% [markdown]
# # Зона для коммитов

# %% [markdown]
# Передадим файл в репозиторий

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 9 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 9 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Добавил текст в репозиторий"
# Out:
# [master 03af83c] Добавил текст в репозиторий
#  1 file changed, 1 deletion(-)
#  delete mode 100644 conspects_KirichekM.ipynb

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Vaaagos/Screwu2.git (fetch)
# origin	https://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@github.com/Vaaagos/Screwu2.git (push)

# %%
# !git push origin master
# Out:
# To https://github.com/Vaaagos/Screwu2.git
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://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@github.com/Vaaagos/Screwu2.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
