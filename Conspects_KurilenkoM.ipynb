# %% [markdown]
# Настройка Git
# * имя и майл
# * получить токен

# %%
# !git config --global user.name "Macxim23
# !git config --global user.email "imizzerro2@mail.ru"
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
token = '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'
username = 'Vaaagos'
repo = 'Screwu2'

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# fatal: destination path 'Screwu2' already exists and is not an empty directory.

# %%
# !mv Conspects_KurilenkoM.ipynb Screwu2/
# Out:
# mv: cannot stat 'Conspects_KurilenkoM.ipynb': No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/Screwu2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Screwu2

# %% [markdown]
# Зона для комитов

# %%
# !git add .

# %%
# !git status
# Out:
# On branch KurikenkoM
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   Conspects_KurilenkoM.ipynb

# %%
# !git commit -m "добавил ветку KurilenkoM"
# Out:
# [KurilenkoM 520f081] добавил ветку KurilenkoM
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Conspects_KurilenkoM.ipynb (79%)

# %%
token = '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'
username = 'Vaaagos'
repo = 'Screwu2'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Vaaagos/Screwu2.git (fetch)
# origin	https://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@github.com/Vaaagos/Screwu2.git (push)

# %%
# !git push origin KurilenkoM
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 5.41 KiB | 791.00 KiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# remote:
# remote: Create a pull request for 'KurilenkoM' on GitHub by visiting:
# remote:      https://github.com/Vaaagos/Screwu2/pull/new/KurilenkoM
# remote:
# To https://github.com/Vaaagos/Screwu2.git
#  * [new branch]      KurilenkoM -> KurilenkoM

# %%
# !git pull origin KurilenkoM
# Out:
# From https://github.com/Vaaagos/Screwu2
#  * branch            KurilenkoM -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# Журнал коммитов

# %%
# !git log
# Out:
# commit f4b1d44fb8304d16122b4d2c3d23020e94b2c756 (HEAD -> master, origin/master, origin/HEAD)
# Merge: c5397a3 465490d
# Author: root <imizzerro2@mail.ru>
# Date:   Fri Feb 17 08:18:11 2023 +0000
#
#     добавил текст в репозиторий
#
# commit c5397a398e2914a0afadb2ee0ffc2d46312ee2ff
# Author: Macxim23 <imizzerro2@mail.ru>
# Date:   Fri Feb 17 07:32:30 2023 +0000
#
#     файл в репозитории
#
# commit d7364305eb3a18e869889aa129b55662aed83b4d
# Author: Macxim23 <imizzerro2@mail.ru>
# Date:   Fri Feb 17 07:30:25 2023 +0000
#
#     файл в репозитории
#
# commit 4dd8246777aa40431e44921594748933dda9a51e
# Author: Macxim23 <imizzerro2@mail.ru>
# Date:   Fri Feb 17 07:18:07 2023 +0000
#
#     файл в репозитории
#
# commit 465490d312df440013a98d7adba82eec21ed6826
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Fri Feb 17 07:00:42 2023 +0000
#
#     Добавил текст раздел log
#
# commit f0cdf77bf6f799edd75743c8c45d0e36f36d065a
# Merge: 4a9d830 57e994a
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Fri Feb 17 06:45:28 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit 4a9d830c001cc245ed1cbac9b84d7eddae2ea3a1
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Fri Feb 17 06:37:34 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit 97fb778c1fef4d512a299d0b0f28b0309cf6a1e9
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Fri Feb 17 06:34:10 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit c2a07aa9d016c11d7c7ec5ecf52c23f7ef878e7e
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Fri Feb 17 06:08:25 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit 3bb33b0ea17c985b02542e3f2cd09f2316177dd5
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Fri Feb 17 05:55:54 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit 7dd5d134f84538bb43757b4dcf9de78667c6c037
# Author: Macxim23 <imizzerro2@mail.ru>
# Date:   Thu Feb 16 22:48:22 2023 +0000
#
#     файл в репозитории
#
# commit 03af83cc1b8712f053f16938690357285bfb9f0b
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 22:42:39 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit 849cd5a3d7c9012d153f5799b1e574c33b55923f
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 22:35:24 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit c3a8d440ab0d3e82850aec9dba4c57f64fcbc574
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 22:32:58 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit 3d2d8ac1e072d777d30ecf930f9a726fc9437a6a
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 22:32:13 2023 +0000
#
#     Добавил текст в репозиторий
#
# commit f36525084fecd87e1f2dd592764cfbed36b8f20e
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 22:09:16 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit bd5b14305c20f0969debe6b917438704862e249d
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 22:08:44 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 57e994a709c52742144417c91766b0f5e7e861a2
# Author: Macxim23 <imizzerro2@mail.ru>
# Date:   Thu Feb 16 22:07:09 2023 +0000
#
#     файл в репозитории
#
# commit 73c97ba0e169770687ce8710e24c3a071426c76f
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 21:54:38 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 873e1373cb72c7d4e0b2c913346b4216dfbe2048
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 21:29:35 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 54ef082480352f217d7154333ccaa9817cd4e8b1 (origin/main)
# Author: vaaagos <vaaagos@mail.ru>
# Date:   Thu Feb 16 21:09:50 2023 +0000
#
#     Добавил раздел log
#
# commit c8b2b5e9d5511f4a00f3bd67eb5f712842cb15be
# Author: Maksimkakir <mj292580@gmail.com>
# Date:   Thu Feb 16 21:09:12 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 309a8e383236032f59dd84b962ca122b3f3aed12
# Author: vaaagos <vaaagos@mail.ru>
# Date:   Thu Feb 16 20:43:06 2023 +0000
#
#     Добавил текст lol
#
# commit 0c04a3581d784d0c544daff7058a39b288ab34be
# Author: vaaagos <vaaagos@mail.ru>
# Date:   Thu Feb 16 20:38:34 2023 +0000
#
#     Добавил списковое включение
#
# commit bc119ecf402107ef846c2eff9d3924724b1940a4
# Author: vaaagos <vaaagos@mail.ru>
# Date:   Thu Feb 16 20:06:42 2023 +0000
#
#     Добавил свой новый файл в репозиторий

# %%
# !git log --oneline
# Out:
# f4b1d44 (HEAD -> master, origin/master, origin/HEAD) добавил текст в репозиторий
# c5397a3 файл в репозитории
# d736430 файл в репозитории
# 4dd8246 файл в репозитории
# 465490d Добавил текст раздел log
# f0cdf77 Добавил текст в репозиторий
# 4a9d830 Добавил текст в репозиторий
# 97fb778 Добавил текст в репозиторий
# c2a07aa Добавил текст в репозиторий
# 3bb33b0 Добавил текст в репозиторий
# 7dd5d13 файл в репозитории
# 03af83c Добавил текст в репозиторий
# 849cd5a Добавил текст в репозиторий
# c3a8d44 Добавил текст в репозиторий
# 3d2d8ac Добавил текст в репозиторий
# f365250 Добавил свой новый файл в репозиторий
# bd5b143 Добавил свой новый файл в репозиторий
# 57e994a файл в репозитории
# 73c97ba Добавил свой новый файл в репозиторий
# 873e137 Добавил свой новый файл в репозиторий
# 54ef082 (origin/main) Добавил раздел log
# c8b2b5e Добавил свой новый файл в репозиторий
# 309a8e3 Добавил текст lol
# 0c04a35 Добавил списковое включение
# bc119ec Добавил свой новый файл в репозиторий

# %% [markdown]
# ветвление Git

# %%
# !git branch
# Out:
# * main

# %%
# !git branch -M main

# %%
# !git checkout -b KurilenkoM
# Out:
# Switched to a new branch 'KurilenkoM'
